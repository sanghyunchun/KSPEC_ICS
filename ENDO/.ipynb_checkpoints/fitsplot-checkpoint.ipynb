# %%
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
hdul=fits.open('./endo_controller/data/Test.fits')

# %%
data=hdul[0].data
print(data)
# Out:
# [[ 12  12  12 ...  60  60  60]
#  [ 12  12  12 ...  60  60  61]
#  [ 12  12  12 ...  60  61  61]
#  ...
#  [ 30  29  28 ... 179 179 179]
#  [ 31  31  29 ... 179 179 179]
#  [ 33  32  31 ... 179 179 179]]

# %%
plt.imshow(data,origin='lower')
